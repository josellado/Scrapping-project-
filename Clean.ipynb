# %%
import pandas as pd
import numpy as np
import re

# %%
harry_potter = pd.read_csv("input/harry_potter/Characters.csv", sep =';', index_col=0, encoding ='latin')
harry_potter
# Out:
#                                         Name  Gender  \
# Id
# 1                         Harry James Potter    Male
# 2                      Ronald Bilius Weasley    Male
# 3                      Hermione Jean Granger  Female
# 4    Albus Percival Wulfric Brian Dumbledore    Male
# 5                              Rubeus Hagrid    Male
# ..                                       ...     ...
# 136                 Wilhelmina Grubbly-Plank  Female
# 137                          Fenrir Greyback    Male
# 138                      Gellert Grindelwald    Male
# 139                                    Dobby    Male
# 140                                 Kreacher    Male
#
#                                                    Job       House  \
# Id
# 1                                              Student  Gryffindor
# 2                                              Student  Gryffindor
# 3                                              Student  Gryffindor
# ...

# %%
#shark_study['Species '] =shark_study['Species '].fillna("unknown species")

harry_potter= harry_potter.fillna('Unknown')
harry_potter.head()
# Out:
#                                        Name  Gender  \
# Id
# 1                        Harry James Potter    Male
# 2                     Ronald Bilius Weasley    Male
# 3                     Hermione Jean Granger  Female
# 4   Albus Percival Wulfric Brian Dumbledore    Male
# 5                             Rubeus Hagrid    Male
#
#                                                   Job       House  \
# Id
# 1                                             Student  Gryffindor
# 2                                             Student  Gryffindor
# 3                                             Student  Gryffindor
# 4                                          Headmaster  Gryffindor
# 5   Keeper of Keys and Grounds | Professor of Care...  Gryffindor
#
#                                   Wand              Patronus  \
# Id
# 1          11"  Holly  phoenix feather                  Stag
# 2           12" Ash unicorn tail hair   Jack Russell terrier
# ...

# %%
harry_potter = harry_potter.drop_duplicates()

harry_potter = harry_potter.drop(columns = ['Birth', 'Death', "Loyalty"])
harry_potter.shape
# Out:
# (140, 11)

# %%
harry_potter.isnull().sum()
# Out:
# Name            0
# Gender          0
# Job             0
# House           0
# Wand            0
# Patronus        0
# Species         0
# Blood status    0
# Hair colour     0
# Eye colour      0
# Skills          0
# dtype: int64

# %%
harry_potter.head(60)
# Out:
#                                         Name   Gender  \
# Id
# 1                         Harry James Potter     Male
# 2                      Ronald Bilius Weasley     Male
# 3                      Hermione Jean Granger   Female
# 4    Albus Percival Wulfric Brian Dumbledore     Male
# 5                              Rubeus Hagrid     Male
# 6                         Neville Longbottom     Male
# 7                               Fred Weasley     Male
# 8                             George Weasley     Male
# 9              Ginevra (Ginny) Molly Weasley   Female
# 10                               Dean Thomas     Male
# 11                           Seamus Finnigan     Male
# 12                            Lily J. Potter   Female
# 13                              James Potter     Male
# 14                              Sirius Black     Male
# 15                          Remus John Lupin     Male
# 16                           Peter Pettigrew     Male
# ...

# %%
harry_potter.to_csv("output/harry_potter_Clean.csv")
